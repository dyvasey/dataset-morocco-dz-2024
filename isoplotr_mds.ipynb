# %% [markdown]
# ## Create MDS plots using IsoplotR

# %%
import pandas as pd

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library('IsoplotR')
# sessionInfo()
# Out:
# R version 4.1.3 (2022-03-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 22.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/dyvasey/miniforge3/envs/dataset-morocco-dz-2024/lib/libopenblasp-r0.3.28.so
#
# locale:
#  [1] LC_CTYPE=C.UTF-8       LC_NUMERIC=C           LC_TIME=C.UTF-8
#  [4] LC_COLLATE=C.UTF-8     LC_MONETARY=C.UTF-8    LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C.UTF-8       LC_NAME=C              LC_ADDRESS=C
# [10] LC_TELEPHONE=C         LC_MEASUREMENT=C.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] tools     stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
# [1] IsoplotR_5.2
#
# loaded via a namespace (and not attached):
# [1] compiler_4.1.3

# %%
# %%R
# filenames <- dir('isoplotr/input_data',pattern='*.csv')
# print(filenames)
# Out:
#  [1] "01MCO.csv"           "02MCO.csv"           "03MCO.csv"
#  [4] "04MCO.csv"           "05MCO.csv"           "06MCO.csv"
#  [7] "07MCO.csv"           "08MCO.csv"           "09MCO.csv"
# [10] "10MCO.csv"           "11MCO.csv"           "12MCO.csv"
# [13] "13MCO.csv"           "14MCO.csv"           "15MCO.csv"
# [16] "16MCO.csv"           "ages.csv"            "domenech_ages.csv"
# [19] "laserchron_ages.csv" "marzoli_ages.csv"    "Mi39T.csv"
# [22] "Mi40T.csv"           "Mi48T.csv"           "Mi49T.csv"
# [25] "Mi63T.csv"           "MR24-006.csv"        "MR24-008.csv"
# [28] "MR24-009.csv"        "MR24-017.csv"        "MR24-020.csv"
# [31] "MR24-023.csv"        "NEV24-001.csv"       "NEV24-002.csv"
# [34] "NEV24-003.csv"       "perez_ages.csv"

# %%
# Combine ages CSVs in Python
path = 'isoplotr/input_data/'
lc_ages = pd.read_csv(path+'laserchron_ages.csv')
lc_ages_noNE = lc_ages.iloc[:,:-3] # Exclude NE samples

dom_ages = pd.read_csv(path+'domenech_ages.csv')

per_ages = pd.read_csv(path+'perez_ages.csv')
per_ages_Tronly = per_ages[['06MCO','07MCO','08MCO','09MCO','10MCO','11MCO','13MCO','16MCO']]

mar_ages = pd.read_csv(path+'marzoli_ages.csv')

all_ages = pd.concat([lc_ages_noNE,dom_ages,per_ages_Tronly,mar_ages],axis=1)
all_ages.to_csv(path+'all_ages.csv',index=False)

# %%
# %%R
# # Get MDS file and do MDS analysis
# path <- 'isoplotr/input_data/'
#
# dz <- read.data(file.path(path,'all_ages.csv'),method='detritals')
# plot_path <- file.path(path,'mds_plot.pdf')
#
# pdf(plot_path)
# mds(dz,nnlines=FALSE,pch=21,cex=3)
# dev.off()
# Out:
# [1] "KS"
# initial  value 16.689994
# iter   5 value 11.822368
# iter  10 value 11.490550
# final  value 11.372684
# converged
# png
#   2
