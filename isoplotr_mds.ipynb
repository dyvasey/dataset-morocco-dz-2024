# %% [markdown]
# ## Create MDS plots using IsoplotR

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages('IsoplotR',.libPaths()[2])
# Out:
# R[write to console]: Warning in install.packages("IsoplotR", .libPaths()[2]) :
# R[write to console]:
#
# R[write to console]:  'lib = "NA"' is not writable
#
# R[write to console]: Error in install.packages("IsoplotR", .libPaths()[2]) :
#   unable to install packages
# Error in install.packages("IsoplotR", .libPaths()[2]) :
#   unable to install packages
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/miniforge3/envs/dataset-morocco-dz-2024/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:385, in RMagics.eval(self, code)
#     383 try:
#     384     # Need the newline in case the last line in code is a comment.
# --> 385     value, visible = ro.r("withVisible({%s\n})" % code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#
# ...

# %%
# %%R
# library('IsoplotR')
# sessionInfo()
# Out:
# R[write to console]: Error in library("IsoplotR") : there is no package called ‘IsoplotR’
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In install.packages("IsoplotR") :
# R[write to console]:
#
# R[write to console]:  installation of package ‘IsoplotR’ had non-zero exit status
# Error in library("IsoplotR") : there is no package called ‘IsoplotR’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/miniforge3/envs/dataset-morocco-dz-2024/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:385, in RMagics.eval(self, code)
#     383 try:
#     384     # Need the newline in case the last line in code is a comment.
# --> 385     value, visible = ro.r("withVisible({%s\n})" % code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#
# ...
