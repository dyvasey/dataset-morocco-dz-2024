# %% [markdown]
# ## Create MDS plots using IsoplotR

# %%
import pandas as pd

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library('IsoplotR')
# sessionInfo()
# Out:
# R version 4.1.3 (2022-03-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Freedesktop SDK 24.08 (Flatpak runtime)
#
# Matrix products: default
# BLAS/LAPACK: /var/home/dyvasey/miniforge3/envs/dataset-morocco-dz-2024/lib/libopenblasp-r0.3.28.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] tools     stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
# [1] IsoplotR_5.2
#
# loaded via a namespace (and not attached):
# [1] compiler_4.1.3

# %%
# %%R
# filenames <- dir('isoplotr/input_data',pattern='*.csv')
# print(filenames)
# Out:
# [1] "ages.csv"          "domenech_ages.csv" "Mi39T.csv"
# [4] "Mi40T.csv"         "Mi48T.csv"         "Mi49T.csv"
# [7] "Mi63T.csv"

# %%
# Combine ages CSVs in Python
path = 'isoplotr/input_data/'
lc_ages = pd.read_csv(path+'laserchron_ages.csv')
lc_ages_noNE = lc_ages.iloc[:,:-3] # Exclude NE samples

dom_ages = pd.read_csv(path+'domenech_ages.csv')
all_ages = pd.concat([lc_ages_noNE,dom_ages],axis=1)
all_ages.to_csv(path+'all_ages.csv',index=False)
# Out:
# Index(['MR24-006', 'MR24-008', 'MR24-009', 'MR24-017', 'MR24-020', 'MR24-023'], dtype='object')

# %%
# %%R
# # Get MDS file and do MDS analysis
# path <- 'isoplotr/input_data/'
#
# dz <- read.data(file.path(path,'all_ages.csv'),method='detritals')
# plot_path <- file.path(path,'mds_plot.pdf')
#
# pdf(plot_path)
# mds(dz,nnlines=FALSE,pch=21,cex=3,pos=1)
# dev.off()
# Out:
# [1] "KS"
# initial  value 8.158004
# iter   5 value 5.616523
# iter  10 value 5.054620
# iter  15 value 4.984333
# final  value 4.950101
# converged
# png
#   2
